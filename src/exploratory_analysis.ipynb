# %%
library(tidyverse)

# %%
file <- read_csv("http://data.insideairbnb.com/canada/qc/quebec-city/2019-11-07/data/listings.csv.gz")

airbnb_df <- subset(file, select = -c(summary, space, listing_url, host_url, description, scrape_id, last_scraped, experiences_offered, 
                                      thumbnail_url, medium_url, xl_picture_url, host_acceptance_rate, name, neighbourhood, 
                                      neighborhood_overview, neighbourhood_group_cleansed, host_neighbourhood, jurisdiction_names, 
                                      license, cancellation_policy, notes, transit, access, interaction, house_rules, picture_url, host_about, 
                                      host_thumbnail_url, host_total_listings_count, minimum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, maximum_minimum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, host_picture_url))

#removing '$' from price and fees and converting from string to numeric
airbnb_df$price = as.numeric(gsub("\\$", "", airbnb_df$price)) 
airbnb_df$weekly_price = as.numeric(gsub("\\$", "", airbnb_df$weekly_price))
airbnb_df$monthly_price = as.numeric(gsub("\\$", "", airbnb_df$monthly_price))
airbnb_df$cleaning_fee = as.numeric(gsub("\\$", "", airbnb_df$cleaning_fee))
airbnb_df$security_deposit = as.numeric(gsub("\\$", "", airbnb_df$security_deposit))
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   id = col_double(),
#   scrape_id = col_double(),
#   last_scraped = col_date(format = ""),
#   thumbnail_url = col_logical(),
#   medium_url = col_logical(),
#   xl_picture_url = col_logical(),
#   host_id = col_double(),
#   host_since = col_date(format = ""),
#   host_is_superhost = col_logical(),
#   host_listings_count = col_double(),
#   host_total_listings_count = col_double(),
#   host_has_profile_pic = col_logical(),
#   host_identity_verified = col_logical(),
#   neighbourhood = col_logical(),
#   neighbourhood_group_cleansed = col_logical(),
#   latitude = col_double(),
#   longitude = col_double(),
#   is_location_exact = col_logical(),
#   accommodates = col_double(),
#   bathrooms = col_double()
#   # ... with 40 more columns
# )
#
# See spec(...) for full column specifications.

# %%
summary(airbnb_df)
# Out:
#        id              host_id           host_name           host_since
#  Min.   :   54334   Min.   :   254811   Length:2704        Min.   :2010-10-06
#  1st Qu.:18589259   1st Qu.: 29506103   Class :character   1st Qu.:2015-03-26
#  Median :27903475   Median : 90335665   Mode  :character   Median :2016-08-17
#  Mean   :25784162   Mean   :114600153                      Mean   :2016-08-25
#  3rd Qu.:34839724   3rd Qu.:194055805                      3rd Qu.:2018-06-07
#  Max.   :39942561   Max.   :307893148                      Max.   :2019-11-07
#
#  host_location      host_response_time host_response_rate host_is_superhost
#  Length:2704        Length:2704        Length:2704        Mode :logical
#  Class :character   Class :character   Class :character   FALSE:1897
#  Mode  :character   Mode  :character   Mode  :character   TRUE :807
#
#
#
#
#  host_listings_count host_verifications host_has_profile_pic
#  Min.   :  0.000     Length:2704        Mode :logical
#  1st Qu.:  1.000     Class :character   FALSE:11
#  Median :  2.000     Mode  :character   TRUE :2693
#  Mean   :  7.168
#  3rd Qu.:  5.000
#  Max.   :148.000
#
#  host_identity_verified    street          neighbourhood_cleansed
#  Mode :logical          Length:2704        Length:2704
#  FALSE:2022             Class :character   Class :character
#  TRUE :682              Mode  :character   Mode  :character
#
#
#
#
#      city              state             zipcode             market
#  Length:2704        Length:2704        Length:2704        Length:2704
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  smart_location     country_code         country             latitude
#  Length:2704        Length:2704        Length:2704        Min.   :46.74
#  Class :character   Class :character   Class :character   1st Qu.:46.81
#  Mode  :character   Mode  :character   Mode  :character   Median :46.81
#                                                           Mean   :46.82
#                                                           3rd Qu.:46.83
#                                                           Max.   :46.95
#
#    longitude      is_location_exact property_type       room_type
#  Min.   :-71.47   Mode :logical     Length:2704        Length:2704
#  1st Qu.:-71.26   FALSE:546         Class :character   Class :character
#  Median :-71.23   TRUE :2158        Mode  :character   Mode  :character
#  Mean   :-71.24
#  3rd Qu.:-71.22
#  Max.   :-71.15
#
#   accommodates      bathrooms         bedrooms           beds
#  Min.   : 1.000   Min.   : 0.000   Min.   : 0.000   Min.   : 0.000
#  1st Qu.: 2.000   1st Qu.: 1.000   1st Qu.: 1.000   1st Qu.: 1.000
#  Median : 4.000   Median : 1.000   Median : 1.000   Median : 2.000
#  Mean   : 3.931   Mean   : 1.174   Mean   : 1.564   Mean   : 2.011
#  3rd Qu.: 5.000   3rd Qu.: 1.000   3rd Qu.: 2.000   3rd Qu.: 3.000
#  Max.   :16.000   Max.   :10.000   Max.   :10.000   Max.   :12.000
#                   NA's   :2        NA's   :3        NA's   :12
#    bed_type          amenities          square_feet         price
#  Length:2704        Length:2704        Min.   :  0.00   Min.   : 14.0
#  Class :character   Class :character   1st Qu.:  0.00   1st Qu.: 59.0
#  Mode  :character   Mode  :character   Median :  0.00   Median : 95.0
#                                        Mean   : 50.25   Mean   :121.7
#                                        3rd Qu.:  0.00   3rd Qu.:150.0
#                                        Max.   :603.00   Max.   :950.0
#                                        NA's   :2692     NA's   :57
#   weekly_price   monthly_price   security_deposit  cleaning_fee
#  Min.   :100.0   Min.   :395.0   Min.   :  0.0    Min.   :  0.0
#  1st Qu.:309.0   1st Qu.:550.0   1st Qu.:  0.0    1st Qu.: 20.0
#  Median :467.5   Median :791.0   Median :150.0    Median : 45.0
#  Mean   :484.0   Mean   :734.2   Mean   :175.9    Mean   : 48.7
#  3rd Qu.:659.2   3rd Qu.:899.0   3rd Qu.:300.0    3rd Qu.: 69.5
#  Max.   :998.0   Max.   :995.0   Max.   :999.0    Max.   :425.0
#  NA's   :2568    NA's   :2651    NA's   :941      NA's   :533
#  guests_included  extra_people       minimum_nights    maximum_nights
#  Min.   : 1.000   Length:2704        Min.   :  1.000   Min.   :   1.0
#  1st Qu.: 1.000   Class :character   1st Qu.:  1.000   1st Qu.: 100.0
#  Median : 1.000   Mode  :character   Median :  2.000   Median :1125.0
#  Mean   : 1.888                      Mean   :  5.732   Mean   : 808.7
#  3rd Qu.: 2.000                      3rd Qu.:  2.000   3rd Qu.:1125.0
#  Max.   :12.000                      Max.   :180.000   Max.   :1139.0
#
#  calendar_updated   has_availability availability_30 availability_60
#  Length:2704        Mode:logical     Min.   : 0.00   Min.   : 0.00
#  Class :character   TRUE:2704        1st Qu.: 0.00   1st Qu.: 8.75
#  Mode  :character                    Median :17.00   Median :34.00
#                                      Mean   :15.09   Mean   :30.50
#                                      3rd Qu.:27.00   3rd Qu.:50.00
#                                      Max.   :30.00   Max.   :60.00
#
#  availability_90 availability_365 calendar_last_scraped number_of_reviews
#  Min.   : 0.00   Min.   :  0.0    Min.   :2019-11-07    Min.   :  0.00
#  1st Qu.:21.00   1st Qu.: 60.0    1st Qu.:2019-11-07    1st Qu.:  3.00
#  Median :58.00   Median :164.0    Median :2019-11-07    Median : 20.00
#  Mean   :50.15   Mean   :180.9    Mean   :2019-11-07    Mean   : 42.73
#  3rd Qu.:79.00   3rd Qu.:321.0    3rd Qu.:2019-11-07    3rd Qu.: 58.00
#  Max.   :90.00   Max.   :365.0    Max.   :2019-11-09    Max.   :701.00
#
#  number_of_reviews_ltm  first_review         last_review
#  Min.   :  0.00        Min.   :2011-06-13   Min.   :2015-04-23
#  1st Qu.:  1.00        1st Qu.:2017-07-04   1st Qu.:2019-09-02
#  Median : 10.00        Median :2018-08-11   Median :2019-10-14
#  Mean   : 21.15        Mean   :2018-03-28   Mean   :2019-08-16
#  3rd Qu.: 34.00        3rd Qu.:2019-06-23   3rd Qu.:2019-10-26
#  Max.   :151.00        Max.   :2019-11-05   Max.   :2019-11-07
#                        NA's   :354          NA's   :354
#  review_scores_rating review_scores_accuracy review_scores_cleanliness
#  Min.   : 20.00       Min.   : 2.000         Min.   : 2.000
#  1st Qu.: 91.00       1st Qu.:10.000         1st Qu.: 9.000
#  Median : 96.00       Median :10.000         Median :10.000
#  Mean   : 93.87       Mean   : 9.703         Mean   : 9.548
#  3rd Qu.: 99.00       3rd Qu.:10.000         3rd Qu.:10.000
#  Max.   :100.00       Max.   :10.000         Max.   :10.000
#  NA's   :370          NA's   :370            NA's   :370
#  review_scores_checkin review_scores_communication review_scores_location
#  Min.   : 2.000        Min.   : 2.00               Min.   : 2.000
#  1st Qu.:10.000        1st Qu.:10.00               1st Qu.: 9.000
#  Median :10.000        Median :10.00               Median :10.000
#  Mean   : 9.802        Mean   : 9.76               Mean   : 9.631
#  3rd Qu.:10.000        3rd Qu.:10.00               3rd Qu.:10.000
#  Max.   :10.000        Max.   :10.00               Max.   :10.000
#  NA's   :370           NA's   :370                 NA's   :370
#  review_scores_value requires_license instant_bookable is_business_travel_ready
#  Min.   : 2.000      Mode :logical    Mode :logical    Mode :logical
#  1st Qu.: 9.000      FALSE:2704       FALSE:1080       FALSE:2704
#  Median :10.000                       TRUE :1624
#  Mean   : 9.439
#  3rd Qu.:10.000
#  Max.   :10.000
#  NA's   :370
#  require_guest_profile_picture require_guest_phone_verification
#  Mode :logical                 Mode :logical
#  FALSE:2692                    FALSE:2694
#  TRUE :12                      TRUE :10
#
#
#
#
#  calculated_host_listings_count calculated_host_listings_count_entire_homes
#  Min.   : 1.000                 Min.   : 0.000
#  1st Qu.: 1.000                 1st Qu.: 1.000
#  Median : 2.000                 Median : 1.000
#  Mean   : 5.175                 Mean   : 4.452
#  3rd Qu.: 4.000                 3rd Qu.: 3.000
#  Max.   :50.000                 Max.   :50.000
#
#  calculated_host_listings_count_private_rooms
#  Min.   : 0.0000
#  1st Qu.: 0.0000
#  Median : 0.0000
#  Mean   : 0.6967
#  3rd Qu.: 1.0000
#  Max.   :18.0000
#
#  calculated_host_listings_count_shared_rooms reviews_per_month
#  Min.   :0.000000                            Min.   : 0.020
#  1st Qu.:0.000000                            1st Qu.: 0.840
#  Median :0.000000                            Median : 2.530
#  Mean   :0.009985                            Mean   : 3.176
#  3rd Qu.:0.000000                            3rd Qu.: 4.945
#  Max.   :2.000000                            Max.   :13.640
#                                              NA's   :354

# %%
#finding the names of all columns and their data type
sapply(airbnb_df, class)
# Out:
#                                           id
#                                    "numeric"
#                                      host_id
#                                    "numeric"
#                                    host_name
#                                  "character"
#                                   host_since
#                                       "Date"
#                                host_location
#                                  "character"
#                           host_response_time
#                                  "character"
#                           host_response_rate
#                                  "character"
#                            host_is_superhost
#                                    "logical"
#                          host_listings_count
#                                    "numeric"
#                           host_verifications
#                                  "character"
#                         host_has_profile_pic
#                                    "logical"
#                       host_identity_verified
#                                    "logical"
#                                       street
#                                  "character"
#                       neighbourhood_cleansed
#                                  "character"
#                                         city
#                                  "character"
#                                        state
#                                  "character"
#                                      zipcode
#                                  "character"
#                                       market
#                                  "character"
#                               smart_location
#                                  "character"
#                                 country_code
#                                  "character"
#                                      country
#                                  "character"
#                                     latitude
#                                    "numeric"
#                                    longitude
#                                    "numeric"
#                            is_location_exact
#                                    "logical"
#                                property_type
#                                  "character"
#                                    room_type
#                                  "character"
#                                 accommodates
#                                    "numeric"
#                                    bathrooms
#                                    "numeric"
#                                     bedrooms
#                                    "numeric"
#                                         beds
#                                    "numeric"
#                                     bed_type
#                                  "character"
#                                    amenities
#                                  "character"
#                                  square_feet
#                                    "numeric"
#                                        price
#                                    "numeric"
#                                 weekly_price
#                                    "numeric"
#                                monthly_price
#                                    "numeric"
#                             security_deposit
#                                    "numeric"
#                                 cleaning_fee
#                                    "numeric"
#                              guests_included
#                                    "numeric"
#                                 extra_people
#                                  "character"
#                               minimum_nights
#                                    "numeric"
#                               maximum_nights
#                                    "numeric"
#                             calendar_updated
#                                  "character"
#                             has_availability
#                                    "logical"
#                              availability_30
#                                    "numeric"
#                              availability_60
#                                    "numeric"
#                              availability_90
#                                    "numeric"
#                             availability_365
#                                    "numeric"
#                        calendar_last_scraped
#                                       "Date"
#                            number_of_reviews
#                                    "numeric"
#                        number_of_reviews_ltm
#                                    "numeric"
#                                 first_review
#                                       "Date"
#                                  last_review
#                                       "Date"
#                         review_scores_rating
#                                    "numeric"
#                       review_scores_accuracy
#                                    "numeric"
#                    review_scores_cleanliness
#                                    "numeric"
#                        review_scores_checkin
#                                    "numeric"
#                  review_scores_communication
#                                    "numeric"
#                       review_scores_location
#                                    "numeric"
#                          review_scores_value
#                                    "numeric"
#                             requires_license
#                                    "logical"
#                             instant_bookable
#                                    "logical"
#                     is_business_travel_ready
#                                    "logical"
#                require_guest_profile_picture
#                                    "logical"
#             require_guest_phone_verification
#                                    "logical"
#               calculated_host_listings_count
#                                    "numeric"
#  calculated_host_listings_count_entire_homes
#                                    "numeric"
# calculated_host_listings_count_private_rooms
#                                    "numeric"
#  calculated_host_listings_count_shared_rooms
#                                    "numeric"
#                            reviews_per_month
#                                    "numeric"

# %%
data.frame(unclass(summary(airbnb_df)), check.names = FALSE, stringsAsFactors = FALSE)
# Out:
#           id              host_id           host_name
# X   Min.   :   54334   Min.   :   254811   Length:2704
# X.1 1st Qu.:18589259   1st Qu.: 29506103   Class :character
# X.2 Median :27903475   Median : 90335665   Mode  :character
# X.3 Mean   :25784162   Mean   :114600153   NA
# X.4 3rd Qu.:34839724   3rd Qu.:194055805   NA
# X.5 Max.   :39942561   Max.   :307893148   NA
# X.6 NA                 NA                  NA
#       host_since         host_location      host_response_time
# X   Min.   :2010-10-06   Length:2704        Length:2704
# X.1 1st Qu.:2015-03-26   Class :character   Class :character
# X.2 Median :2016-08-17   Mode  :character   Mode  :character
# X.3 Mean   :2016-08-25   NA                 NA
# X.4 3rd Qu.:2018-06-07   NA                 NA
# X.5 Max.   :2019-11-07   NA                 NA
# X.6 NA                   NA                 NA
#     host_response_rate host_is_superhost host_listings_count host_verifications
# X   Length:2704        Mode :logical     Min.   :  0.000     Length:2704
# X.1 Class :character   FALSE:1897        1st Qu.:  1.000     Class :character
# X.2 Mode  :character   TRUE :807         Median :  2.000     Mode  :character
# X.3 NA                 NA                Mean   :  7.168     NA
# X.4 NA                 NA                3rd Qu.:  5.000     NA
# X.5 NA                 NA                Max.   :148.000     NA
# X.6 NA                 NA                NA                  NA
#     ... requires_license instant_bookable is_business_travel_ready
# X   ... Mode :logical    Mode :logical    Mode :logical
# X.1 ... FALSE:2704       FALSE:1080       FALSE:2704
# X.2 ... NA               TRUE :1624       NA
# X.3 ... NA               NA               NA
# X.4 ... NA               NA               NA
# X.5 ... NA               NA               NA
# X.6 ... NA               NA               NA
#     require_guest_profile_picture require_guest_phone_verification
# X   Mode :logical                 Mode :logical
# X.1 FALSE:2692                    FALSE:2694
# X.2 TRUE :12                      TRUE :10
# X.3 NA                            NA
# X.4 NA                            NA
# X.5 NA                            NA
# X.6 NA                            NA
#     calculated_host_listings_count calculated_host_listings_count_entire_homes
# X   Min.   : 1.000                 Min.   : 0.000
# X.1 1st Qu.: 1.000                 1st Qu.: 1.000
# X.2 Median : 2.000                 Median : 1.000
# X.3 Mean   : 5.175                 Mean   : 4.452
# X.4 3rd Qu.: 4.000                 3rd Qu.: 3.000
# X.5 Max.   :50.000                 Max.   :50.000
# X.6 NA                             NA
#     calculated_host_listings_count_private_rooms
# X   Min.   : 0.0000
# X.1 1st Qu.: 0.0000
# X.2 Median : 0.0000
# X.3 Mean   : 0.6967
# X.4 3rd Qu.: 1.0000
# X.5 Max.   :18.0000
# X.6 NA
#     calculated_host_listings_count_shared_rooms reviews_per_month
# X   Min.   :0.000000                            Min.   : 0.020
# X.1 1st Qu.:0.000000                            1st Qu.: 0.840
# X.2 Median :0.000000                            Median : 2.530
# X.3 Mean   :0.009985                            Mean   : 3.176
# X.4 3rd Qu.:0.000000                            3rd Qu.: 4.945
# X.5 Max.   :2.000000                            Max.   :13.640
# X.6 NA                                          NA's   :354

# %% [markdown]
# ## Scatterplot Matrices for select numeric variables of interest

# %%
#airbnb_df['host_listings_count']==airbnb_df['host_total_listings_count']

# %%
options(repr.plot.width = 12, repr.plot.height = 9)

# %%
numeric_1 <- colnames(airbnb_df[ , map_lgl(airbnb_df, is.numeric)])[2:7]
numeric_1[1] = 'price'
numeric_subset1 <- airbnb_df[,numeric_1]

# %%
#plot_1  <- airbnb_df[,c('price','host_listings_count','latitude','longitude','accommodates','bathrooms')]
pairs(numeric_subset1,pch = 21,cex = 0.7,bg="black",col="white",lwd= 0.5, cex.labels=2)
# Out:
# plot without title

# %%
numeric_subset2 <- airbnb_df[,colnames(airbnb_df[ , map_lgl(airbnb_df, is.numeric)])[8:14]]
pairs(numeric_subset2,pch = 21,cex = 1,bg="black",col="white",lwd= 0.5, cex.labels=2)
# Out:
# plot without title

# %%
numeric_3 <- colnames(airbnb_df[ , map_lgl(airbnb_df, is.numeric)])[15:20]
numeric_3[1] = 'price'
numeric_subset3 <- airbnb_df[,numeric_3]

pairs(numeric_subset3,pch = 21,cex = 1,bg="black",col="white",lwd= 0.5, cex.labels=2)
# Out:
# plot without title

# %%
numeric_4 <- colnames(airbnb_df[ , map_lgl(airbnb_df, is.numeric)])[21:26]
numeric_4[1] = 'price'
numeric_subset4 <- airbnb_df[,numeric_4]
pairs(numeric_subset4,pch = 21,cex = 1,bg="black",col="white",lwd= 0.5, cex.labels=2)
# Out:
# plot without title

# %%
numeric_5 <- colnames(airbnb_df[ , map_lgl(airbnb_df, is.numeric)])[27:32]
numeric_5[1] = 'price'
numeric_subset5 <- airbnb_df[,numeric_5]
pairs(numeric_subset5,pch = 21,cex = 1,bg="black",col="white",lwd= 0.5, cex.labels=2)
# Out:
# plot without title

# %%
numeric_6 <- colnames(airbnb_df[ , map_lgl(airbnb_df, is.numeric)])[33:36]
numeric_6[1] = 'price'
numeric_subset6 <- airbnb_df[,numeric_6]

pairs(numeric_subset6,pch = 21,cex = 1,bg="black",col="white",lwd= 0.5, cex.labels=2)
# Out:
# plot without title

# %%
#Todo

#Count of property type, room type, barplot
#ggpairs() warnings are annoying
#Remove NAs.

# %%
library(GGally)

numeric_subset1 %>% 
    ggpairs(na.rm = TRUE)%>%
    print(progress = F)
# Out:
# plot without title

# %%
numeric_subset2 %>%
    ggpairs(na.rm = TRUE)%>%
    print(progress = F)
# Out:
# plot without title

# %%
numeric_subset3 %>%
    ggpairs(na.rm = TRUE)%>%
    print(progress = F)
# Out:
# plot without title

# %%
numeric_subset4 %>%
    ggpairs(na.rm = TRUE)%>%
    print(progress = F)
# Out:
# plot without title

# %%
numeric_subset5 %>%
    ggpairs(na.rm = TRUE)%>%
    print(progress = F)
# Out:
# plot without title

# %%
numeric_subset6 %>%
    ggpairs(na.rm = TRUE)%>%
    print(progress = F)
# Out:
# plot without title
